# %%
-- INHERITANCE --
Inheritance atau Pewarisan/Penurunan adalah konsep pemrograman dimana sebuah class dapat ‘menurunkan’ property dan method yang 
dimilikinya kepada class lain. Konsep inheritance membuat sebuah struktur atau ‘hierarchy’ class dalam kode program.
Class yang akan ‘diturunkan’ bisa disebut sebagai class induk (parent class), super class, atau base class. 
Sedangkan class yang ‘menerima penurunan’ bisa disebut sebagai class anak (child class), sub class, derived class atauheir class.

Suatu class yang mempunyai class turunan dinamakan parent class atau base class. 
Sedangkan class turunan itu sendiri seringkali disebut subclass atau child class. 
Suatu subclass dapat mewarisi apa-apa yang dipunyai oleh parent class.
Karena suatu subclass dapat mewarisi apa apa yang dipunyai oleh parent class-nya, 
maka member dari suatu subclass adalah terdiri dari apa-apa yang ia punyai dan juga apa-apa yang ia warisi dari class parent-nya.

# %%
#CONTOH 1:

#mendefinisikan kelas dasar bernama Pengguna yang dipanggil brian.
"""""""""
class User: name = ""   def __init__(self, name): 
        self.name = name   
        def printName(self): 
                    print "Name = " + self.name   
brian = User("brian") brian.printName() 
"""""""""

#membuat kelas lain yang disebut Programmer. 
#terlihat sangat mirip kelas standar kecuali dari Pengguna diberikan parameter. 
#ini berarti semua fungsi kelas Pengguna dapat diakses di kelas Programmer.
"""""""""
class Programmer(User):   
    def __init__(self, name): 
        self.name = name 
    def doPython(self): 
        print "Programming Python"

# %%
#Detail Contoh:

class User:
    def __init__(self,name):
        self.name = name
    def printName(self):
        print("Name = " + self.name)
        
class Programmer(User): #--> Super (Inheritance - SuperClass). Tugas1
    def __init__(self,name):
        User.__init__(self,name)
        
    def doPython(self):
        print("Progamming Python")


#Brian adalah instance dari Pengguna dan hanya dapat mengakses metode printName. 
#Diana adalah contoh Programmer, kelas dengan warisan dari Pengguna, dan dapat mengakses kedua metode di Programmer dan Pengguna.
brian = User("brian") 
brian.printName()

diana = Programmer("Diana") 
diana.printName() 
diana.doPython() 

#Output:
"""""""""
Name = brian 
Name = Diana 
Programming Python
# Out:
#   File "<ipython-input-10-f53174dc5d6b>", line 21
#     brian.printName()
#                       ^
# SyntaxError: invalid character in identifier

# %%
#CONTOH 2:

#membuat kelas induk ikan yang nantinya akan digunakan untuk membuat jenis ikan sebagai subkelasnya. 
#Setiap ikan ini akan memiliki nama depan dan nama belakang selain karakteristik.
"""""""""
class Fish: 
    def __init__(self, first_name, last_name="Fish"): 
        self.first_name = first_name 
        self.last_name = last_name 
"""""""""

#menambahkan beberapa metode lain:
"""""""""
class Fish: 
    def __init__(self, first_name, last_name="Fish"): 
        self.first_name = first_name 
        self.last_name = last_name 
    def swim(self): 
        print("The fish is swimming.") 
    def swim_backwards(self): 
        print("The fish can swim backwards.")

# %%
#Detail Contoh 2:
#PARENT CLASS
#menambahkan beberapa atribut ke metode __init __ ():
class Fish: 
	def __init__(self, first_name, last_name="Fish", skeleton="bone", eyelids=False): 
		self.first_name = first_name 
		self.last_name = last_name 
		self.skeleton = skeleton 
		self.eyelids = eyelids 
	def swim(self): 
		print("The fish is swimming.") 
	def swim_backwards(self): 
		print("The fish can swim backwards.") 

#CHILD CLASSES
#Child atau subclass adalah kelas yang akan diwariskan dari kelas induk. 
#Itu berarti bahwa setiap kelas anak akan dapat menggunakan metode dan variabel kelas induk.
Sebagai contoh, kelas anak Terryfish yang subclass kelas Ikan akan dapat menggunakan metode berenang () yang dinyatakan dalam Ikan tanpa perlu mendeklarasikannya.
"""""""""
class Trout
	(Fish): pass 
"""""""""

#membuat objek Trout tanpa harus mendefinisikan metode tambahan apa pun.
 
class Trout
	(Fish): pass 
    
terry = Trout("Terry") 
print(terry.first_name + " " + terry.last_name) 
print(terry.skeleton) 
print(terry.eyelids) 
terry.swim() 
terry.swim_backwards() 

#Output:
"""""""""
Terry Fish 
bone 
False 
The fish is swimming. 
The fish can swim backwards. 
"""""""""

# %%
#membuat kelas anak lain yang menyertakan metodenya sendiri dengan memanggil Clownfish kelas.
#membuat objek Clownfish
class Clownfish(Fish): 
	def live_with_anemone(self): 
		print("The clownfish is coexisting with sea anemone.") 

casey = Clownfish("Casey") 
print(casey.first_name + " " + casey.last_name) 
casey.swim() 
casey.live_with_anemone() 

#Output:
"""""""""
Casey Fish 
The fish is swimming. 
The clownfish is coexisting with sea anemone.  
"""""""""
Output menunjukkan: casey objek Clownfish dapat menggunakan metode Fish __init __ () dan
berenang () serta metode kelas turunannya dari live_with_anemone ().

# %%
#EXAMPLE

class Fish:
    def __init__(self,first_name,last_name="Fish",skeleton="bone",eyelids=False):
        self.first_name = first_name
        self.last_name = last_name
        self.skeleton = skeleton
        self.eyelids = eyelids
    
    def swim(self):
        print("The Fish is swimming")
        
    def swim_backwards(self):
        print("The fish can swim backwards")
        
class Trout(Fish):
        pass
    
class Clownfish(Fish):
    def live_with_anemone(self):
        print("The clownfish is coexisting with sea anemone.")
        
terry = Trout("Terry")
print(terry.first_name + " " + terry.last_name)
print(terry.skeleton)
print(terry.eyelids)
terry.swim()
terry.swim_backwards()

terry1 = Trout("TerryS", "SmallFish", "no bone", True)
print(terry1.first_name + " " + terry.last_name)
print(terry1.skeleton)
print(terry1.eyelids)

casey = Clownfish("Casey")
print(casey.first_name + " " + casey.last_name)
casey.swim()
casey.live_with_anemone()
